# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#To load the csv file
df=pd.read_csv("Data_set.csv")

# %% [markdown]
# # Task 7: Common Information Sources

# %% [markdown]
# 1)Explore Information Sources Column: Review the column where participants indicated their sources of investment information.
#
# 2)Identify Common Sources: Analyze the data to identify and summarize the most common sources participants rely on

# %%
#To view the sample data
df.sample(3)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 27    Male   31                Yes             2              3           7
# 32    Male   27                Yes             2              4           7
# 25  Female   32                Yes             3              4           7
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 27                 6               4    1     5  ...  1-3 years
# 32                 5               1    3     6  ...  3-5 years
# 25                 5               1    2     6  ...  3-5 years
#
#    Invest_Monitor   Expect          Avenue What are your savings objectives?  \
# 27        Monthly  20%-30%  Fixed Deposits                       Health Care
# 32        Monthly  30%-40%          Equity                       Health Care
# 25        Monthly  20%-30%     Mutual Fund                   Retirement Plan
#
#            Reason_Equity         Reason_Mutual     Reason_Bonds  \
# ...

# %%
#To view the Source data
df["Source"]
# Out:
# 0     Newspapers and Magazines
# 1        Financial Consultants
# 2                   Television
# 3                     Internet
# 4                     Internet
# 5                     Internet
# 6        Financial Consultants
# 7     Newspapers and Magazines
# 8                   Television
# 9     Newspapers and Magazines
# 10       Financial Consultants
# 11       Financial Consultants
# 12                    Internet
# 13    Newspapers and Magazines
# 14       Financial Consultants
# 15    Newspapers and Magazines
# 16                  Television
# 17       Financial Consultants
# 18    Newspapers and Magazines
# 19    Newspapers and Magazines
# 20       Financial Consultants
# 21    Newspapers and Magazines
# 22       Financial Consultants
# 23       Financial Consultants
# 24    Newspapers and Magazines
# 25       Financial Consultants
# 26       Financial Consultants
# 27                  Television
# 28                  Television
# 29    Newspapers and Magazines
# ...

# %%
#to view the info of the Source column
df["Source"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40 entries, 0 to 39
# Series name: Source
# Non-Null Count  Dtype
# --------------  -----
# 40 non-null     object
# dtypes: object(1)
# memory usage: 452.0+ bytes

# %%
#To check any null values
df["Source"].isnull().sum()
# Out:
# 0

# %%
#To view the summary of source column
df["Source"].describe()
# Out:
# count                        40
# unique                        4
# top       Financial Consultants
# freq                         16
# Name: Source, dtype: object

# %%
#To view the unique values in the column
df["Source"].unique()
# Out:
# array(['Newspapers and Magazines', 'Financial Consultants', 'Television',
#        'Internet'], dtype=object)

# %%
#To view the indivitual values counts in the column
df["Source"].value_counts()
# Out:
# Source
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: count, dtype: int64

# %%
#To plot the countplot
y=sns.countplot(data=df, x=df["Source"].sort_index(ascending=False))
for i in y.containers:
    y.bar_label(i,)
plt.title("Source")
plt.xticks(rotation=90)
plt.show()

# %%
#To plot pie chart;
Source_count= df['Source'].value_counts()
plt.pie(Source_count, labels=Source_count.index, autopct='%1.1f%%', startangle=90)
plt.title('Source')
plt.show()

# %% [markdown]
# Analysing Summary:
#
# 1)From the info,it describes that the Source column is in object datatype and also it has no null values
#
# 2)From the summary,it describes that:
#
#       a)There are 40 rows in the column
#
#       b)There are 4 unique values in the column
#                ->Newspapers and Magazines
#                ->Financial Consultants
#                ->Television
#                ->Internet
#      c)the most common is FinancialConsultants
#
# 3)From the value counts it shows that the Financial Consultants has the highest number of count and Internet has the lowest number of count
#
# 4)The above summary is represented graphically using countplot and Pie chart

# %% [markdown]
# # Task 8: Investment Duration

# %% [markdown]
# 1)Analyze Investment Duration Column: Examine the column containing information about participants' investment durations.
#
# 2)Calculate Average Duration: Use appropriate statistical methods to calculate the average investment duration.

# %%
#To view the 5 sample data
df.sample(5)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 19    Male   26                Yes             3              4           6
# 0   Female   34                Yes             1              2           5
# 38    Male   31                Yes             2              4           7
# 3     Male   22                Yes             2              1           3
# 29  Female   34                Yes             5              4           3
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...          Duration  \
# 19                 5               1    2     7  ...         3-5 years
# 0                  3               7    6     4  ...         1-3 years
# 38                 5               3    1     6  ...         1-3 years
# 3                  7               6    4     5  ...  Less than 1 year
# 29                 2               7    1     6  ...         3-5 years
#
#    Invest_Monitor   Expect          Avenue What are your savings objectives?  \
# ...

# %%
#To view the Duration column
df["Duration"]
# Out:
# 0             1-3 years
# 1     More than 5 years
# 2             3-5 years
# 3      Less than 1 year
# 4      Less than 1 year
# 5             1-3 years
# 6             3-5 years
# 7             3-5 years
# 8             1-3 years
# 9             3-5 years
# 10            3-5 years
# 11            1-3 years
# 12            1-3 years
# 13            1-3 years
# 14            1-3 years
# 15            1-3 years
# 16            1-3 years
# 17            1-3 years
# 18            1-3 years
# 19            3-5 years
# 20            3-5 years
# 21            3-5 years
# 22            3-5 years
# 23            3-5 years
# 24            3-5 years
# 25            3-5 years
# 26            3-5 years
# 27            1-3 years
# 28            1-3 years
# 29            3-5 years
# 30            1-3 years
# 31            3-5 years
# 32            3-5 years
# 33            1-3 years
# 34            1-3 years
# 35            3-5 years
# 36            1-3 years
# 37            3-5 years
# ...

# %%
#to view the info of the Duration column
df["Duration"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40 entries, 0 to 39
# Series name: Duration
# Non-Null Count  Dtype
# --------------  -----
# 40 non-null     object
# dtypes: object(1)
# memory usage: 452.0+ bytes

# %%
#To check any null values
df["Duration"].isnull().sum()
# Out:
# 0

# %%
#To view the summary of Duration column
df["Duration"].describe()
# Out:
# count            40
# unique            4
# top       3-5 years
# freq             19
# Name: Duration, dtype: object

# %%
#To view the unique values in the column
df["Duration"].unique()
# Out:
# array(['1-3 years', 'More than 5 years', '3-5 years', 'Less than 1 year'],
#       dtype=object)

# %%
#To view the indivitual values counts in the column
df["Duration"].value_counts()
# Out:
# Duration
# 3-5 years            19
# 1-3 years            18
# Less than 1 year      2
# More than 5 years     1
# Name: count, dtype: int64

# %%
#To view the mode(frequent repeated value) in the column
df["Duration"].mode()
# Out:
# 0    3-5 years
# Name: Duration, dtype: object

# %%
#Converting to numerical values by using replace function
df["Duration"][df["Duration"]=="1-3 years"]=df["Duration"][df["Duration"]=="1-3 years"].replace('1-3 years',2).astype(float)
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_18504\2413790505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Duration"][df["Duration"]=="1-3 years"]=df["Duration"][df["Duration"]=="1-3 years"].replace('1-3 years',2).astype(float)

# %%
df["Duration"][df["Duration"]=="3-5 years"]=df["Duration"][df["Duration"]=="3-5 years"].replace('3-5 years',4).astype(float)
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_18504\285761467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Duration"][df["Duration"]=="3-5 years"]=df["Duration"][df["Duration"]=="3-5 years"].replace('3-5 years',4).astype(float)

# %%
df["Duration"][df["Duration"]=="Less than 1 year"]=df["Duration"][df["Duration"]=="Less than 1 year"].replace('Less than 1 year',0.5).astype(float)
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_18504\1038721255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Duration"][df["Duration"]=="Less than 1 year"]=df["Duration"][df["Duration"]=="Less than 1 year"].replace('Less than 1 year',0.5).astype(float)

# %%
df["Duration"][df["Duration"]=="More than 5 years"]=df["Duration"][df["Duration"]=="More than 5 years"].replace('More than 5 years',8).astype(float)
# Out:
# C:\Users\prane\AppData\Local\Temp\ipykernel_18504\3606444675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Duration"][df["Duration"]=="More than 5 years"]=df["Duration"][df["Duration"]=="More than 5 years"].replace('More than 5 years',8).astype(float)

# %%
#Duration column after converting to numerical values
df["Duration"]=df["Duration"].astype(float)
df["Duration"].head(5)
# Out:
# 0    2.0
# 1    8.0
# 2    4.0
# 3    0.5
# 4    0.5
# Name: Duration, dtype: float64

# %%
#To view the Summary of Duration column
df["Duration"].describe()
# Out:
# count    40.000000
# mean      3.025000
# std       1.381888
# min       0.500000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       8.000000
# Name: Duration, dtype: float64

# %%
#To view the average Duration
df["Duration"].mean()
# Out:
# 3.025

# %%
#to plot Histogram to view the distribution of duration column
a=sns.histplot(df["Duration"])
for i in a.containers:
    a.bar_label(i,)
plt.title("Distribution of Duration")
plt.show()

# %%
xy=sns.countplot(data=df,x=df["Duration"])
for i in xy.containers:
    xy.bar_label(i,)
plt.title("Duration")
plt.show()

# %% [markdown]
# From the analysing,it shows that 1-3 and 3-5 Years duration is the most common Duration participants rely on

# %% [markdown]
# # Task 9: Expectations from Investments

# %% [markdown]
# 1)Explore Expectations Column: Review the
# column where participants provided
# information about their expectations
#
# 2)List and Describe Expectations: Create a list
# and describe the common expectations
# mentioned by participants.

# %%
#To view the sample data
df.sample(5)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 26    Male   26                Yes             3              4           6
# 22    Male   27                Yes             3              4           6
# 35    Male   30                Yes             1              4           6
# 21  Female   24                Yes             2              4           5
# 5   Female   24                 No             7              5           4
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ... Duration Invest_Monitor  \
# 26                 5               1    2     7  ...      4.0        Monthly
# 22                 5               2    1     7  ...      4.0        Monthly
# 35                 5               3    2     7  ...      4.0        Monthly
# 21                 6               3    1     7  ...      4.0        Monthly
# 5                  6               3    1     2  ...      2.0          Daily
#
# ...

# %%
#To view the Customer expectation data
df['Expect']
# Out:
# 0     20%-30%
# 1     20%-30%
# 2     20%-30%
# 3     10%-20%
# 4     20%-30%
# 5     30%-40%
# 6     20%-30%
# 7     20%-30%
# 8     20%-30%
# 9     30%-40%
# 10    20%-30%
# 11    20%-30%
# 12    20%-30%
# 13    20%-30%
# 14    20%-30%
# 15    20%-30%
# 16    20%-30%
# 17    20%-30%
# 18    20%-30%
# 19    20%-30%
# 20    20%-30%
# 21    20%-30%
# 22    20%-30%
# 23    20%-30%
# 24    30%-40%
# 25    20%-30%
# 26    20%-30%
# 27    20%-30%
# 28    20%-30%
# 29    10%-20%
# 30    10%-20%
# 31    20%-30%
# 32    30%-40%
# 33    20%-30%
# 34    20%-30%
# 35    20%-30%
# 36    20%-30%
# 37    30%-40%
# 38    20%-30%
# 39    20%-30%
# Name: Expect, dtype: object

# %%
#to view the info of the Customer expectation column
df["Expect"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40 entries, 0 to 39
# Series name: Expect
# Non-Null Count  Dtype
# --------------  -----
# 40 non-null     object
# dtypes: object(1)
# memory usage: 452.0+ bytes

# %%
#To check any null values
df["Avenue"].isnull().sum()
# Out:
# 0

# %%
#To view the summary of Customer expectation column
df["Expect"].describe()
# Out:
# count          40
# unique          3
# top       20%-30%
# freq           32
# Name: Expect, dtype: object

# %%
#To view the unique values in the Customer expectation column
df["Expect"].unique()
# Out:
# array(['20%-30%', '10%-20%', '30%-40%'], dtype=object)

# %%
#To view the indivitual values counts in the column
df["Expect"].value_counts()
# Out:
# Expect
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: count, dtype: int64

# %%
#To plot the countplot
x=sns.countplot(x="Expect", data=df)
for i in x.containers:
    x.bar_label(i,)
plt.title("Customer Expectations")
plt.show()

# %%
#To plot the pie chart
Expect_dist= df['Expect'].value_counts()
plt.pie(Expect_dist, labels=Expect_dist.index, autopct='%1.1f%%', startangle=90)
plt.title('Customer Expectations')
plt.show()

# %%
#Converting the column values to list
uni_exp=df["Expect"].unique().tolist()
uni_exp
# Out:
# ['20%-30%', '10%-20%', '30%-40%']

# %%
exp_obj=["In this the minimum range starts from 20% and goes till maximum of 30%",
   "In this the minimum range starts from 10% and goes till maximum of 0%",
        "In this the minimum range starts from 30% and goes till maximum of 40%"]
exp_obj
# Out:
# ['In this the minimum range starts from 20% and goes till maximum of 30%',
#  'In this the minimum range starts from 10% and goes till maximum of 0%',
#  'In this the minimum range starts from 30% and goes till maximum of 40%']

# %%
Exp_obj_des={i:j for i,j in zip(uni_exp,exp_obj)}

# %%
#Final Expectation and their respective summary
Exp_obj_des
# Out:
# {'20%-30%': 'In this the minimum range starts from 20% and goes till maximum of 30%',
#  '10%-20%': 'In this the minimum range starts from 10% and goes till maximum of 0%',
#  '30%-40%': 'In this the minimum range starts from 30% and goes till maximum of 40%'}

# %% [markdown]
# From the Analysis,it show that 20%-30% is the common expectations
# mentioned by participants.

# %% [markdown]
# # Task 10: Correlation Analysis

# %% [markdown]
# 1)Select Relevant Columns: Identify columns
# such as age, investment duration, and
# expected returns for correlation analysis.
#
# 2)Use Statistical Methods or Visualizations:
# Employ statistical methods (e.g., correlation
# coefficients) or visualizations (e.g., scatter
# plots) to explore and visualize potential
# correlations.

# %%
#To view the sample data
df.sample(3)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 9     Male   31                Yes             1              3           7
# 23    Male   25                Yes             2              4           6
# 5   Female   24                 No             7              5           4
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ... Duration Invest_Monitor  \
# 9                  4               5    2     6  ...      4.0        Monthly
# 23                 5               3    1     7  ...      4.0         Weekly
# 5                  6               3    1     2  ...      2.0          Daily
#
#      Expect                 Avenue  What are your savings objectives?  \
# 9   30%-40%         Fixed Deposits                    Retirement Plan
# 23  20%-30%  Public Provident Fund                        Health Care
# 5   30%-40%            Mutual Fund                    Retirement Plan
#
#            Reason_Equity         Reason_Mutual     Reason_Bonds  \
# ...

# %%
#To view the correlation matrix
corr=df.corr(numeric_only=True)
corr
# Out:
#                        age  Mutual_Funds  Equity_Market  Debentures  \
# age               1.000000     -0.123914       0.246840    0.326638
# Mutual_Funds     -0.123914      1.000000       0.332043   -0.351495
# Equity_Market     0.246840      0.332043       1.000000   -0.016898
# Debentures        0.326638     -0.351495      -0.016898    1.000000
# Government_Bonds -0.093632     -0.114198      -0.237420    0.430323
# Fixed_Deposits   -0.033685     -0.031604      -0.238705   -0.470791
# PPF              -0.263167     -0.193665      -0.429003   -0.511169
# Gold             -0.057952     -0.401830      -0.050027   -0.137195
# Duration         -0.004169      0.208454       0.402001   -0.052599
#
#                   Government_Bonds  Fixed_Deposits       PPF      Gold  \
# age                      -0.093632       -0.033685 -0.263167 -0.057952
# Mutual_Funds             -0.114198       -0.031604 -0.193665 -0.401830
# Equity_Market            -0.237420       -0.238705 -0.429003 -0.050027
# ...

# %%
#To plot the heatmap
sns.heatmap(corr,annot=True,cmap="rocket")
plt.show()

# %% [markdown]
# now we are going to plot some scatter plot for age column to see the relation between the columns

# %%
sns.scatterplot(data=df,x="age",y="Mutual_Funds")
plt.title("Age vs Mutual_Funds")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="Equity_Market")
plt.title("Age vs Equity_Market")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="Debentures")
plt.title("Age vs Debentures")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="Government_Bonds")
plt.title("Age vs Government_Bonds")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="Fixed_Deposits")
plt.title("Age vs Fixed_Deposits")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="PPF")
plt.title("Age vs PPF")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="Gold")
plt.title("Age vs Gold")
plt.show()

# %%
sns.scatterplot(data=df,x="age",y="Duration")
plt.title("Age vs Duration")
plt.show()

# %%
#To plot the scatter plot for highest positive correlation columns
sns.scatterplot(data=df,x="Government_Bonds",y="Debentures")
plt.title("Government_Bonds vs Debentures")
plt.show()

# %%
#To plot the scatter plot for highest Negative correlation columns
sns.scatterplot(data=df,x="Government_Bonds",y="Fixed_Deposits")
plt.title("Government_Bonds vs Fixed_Deposits")
plt.show()

# %% [markdown]
# Correlation Summary
#
# 1)The correlation matrix shows the overall relation between each and every columns in the data
#
# 2)The correlation matrix is graphically represented using Heatmap
#
# 3)The scatter plot is also used to represent the relatuion between the 2 numerical columns
#
# 4)Overall the Highest Positive correlation pair is Government_Bonds vs Debentures and the Highest Negative correlation pair is Government_Bonds vs Fixed_Deposits
#
# 5)The both Highest Positive and Negative correlation pair is graphically represented using Heatmap and Scatter plot
